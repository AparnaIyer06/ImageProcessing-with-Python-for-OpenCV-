# %%
#comments are a good practise (every line) (f)

# %% [markdown]
# Don't go line by line- we have provision of going step by step so do that - one line is a bad practice

# %%
from google.colab import drive

# %%
drive.mount("/gdrive")
# Out:
# Mounted at /gdrive

# %%
import os
os.chdir('/gdrive/My Drive/Dataset')

# %% [markdown]
# Drive is also an operation systerm

# %%
import cv2 as cv

# %%
img = cv.imread('monalisa.jpg')

# %%
img
# Out:
# array([[[ 73, 124, 116],
#         [ 75, 126, 118],
#         [ 76, 127, 119],
#         ...,
#         [ 90, 132, 121],
#         [ 87, 118, 109],
#         [ 74,  98,  90]],
#
#        [[ 71, 122, 114],
#         [ 72, 123, 115],
#         [ 73, 124, 116],
#         ...,
#         [ 92, 134, 123],
#         [ 89, 120, 111],
#         [ 75,  99,  91]],
#
#        [[ 72, 124, 117],
#         [ 74, 126, 119],
#         [ 75, 128, 119],
#         ...,
#         [ 93, 135, 124],
#         [ 89, 120, 111],
#         [ 73,  97,  89]],
#
#        ...,
#
#        [[ 68,  80, 108],
#         [ 65,  77, 101],
#         [ 56,  61,  82],
#         ...,
#         [ 62,  56,  73],
#         [ 60,  60,  78],
#         [ 80,  84, 103]],
#
#        [[ 66,  80, 108],
#         [ 62,  73, 100],
#         [ 57,  62,  83],
#         ...,
#         [ 71,  61,  74],
#         [ 61,  56,  71],
#         [ 86,  83,  98]],
#
#        [[ 66,  82, 111],
#         [ 58,  69,  96],
#         [ 61,  65,  84],
# ...

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
cv.cvtcolour(img, cv.COLOR_())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-fd71d04eae72> in <cell line: 1>()
# ----> 1 cv.cvtcolour(img, cv.COLOR_())
#
# AttributeError: module 'cv2' has no attribute 'cvtcolour'

# %%
cv2_imshow(img[:,:, 2])
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
from skimage import io

# %%
import matplotlib.pyplot as plt
import imageio.v3 as io
import pandas as pd

# %%
I7= sitk.ReadImage('microscopic_image.tif')

# %%
# !pip install SimpleITK
import SimpleITK as sitk

# %%
nda = sitk.GetArrayFromImage(I7)

# %%
plt.imshow(nda)
